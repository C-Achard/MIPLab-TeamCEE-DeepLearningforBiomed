# %%
import pickle
from pathlib import Path
import seaborn as sns

from os import environ
environ["KMP_DUPLICATE_LIB_OK"] ="TRUE"

# %%
with Path("attributions.pkl").open("rb") as f:
    attributions = pickle.load(f)

# %%
attributions[0].shape
# Out:
# torch.Size([608, 400, 400])

# %%
attributions[1].shape
# Out:
# torch.Size([608, 400, 400])

# %%
plot = attributions[0].detach().cpu().numpy()
# sns.heatmap(plot, cmap="seismic", center=0)
plot.shape
# Out:
# (608, 400, 400)

# %%
sns.heatmap(plot.mean(axis=0), cmap="seismic", center=0)
# Out:
# <Axes: >
